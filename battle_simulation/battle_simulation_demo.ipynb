# %%
from battle_simulator import *

# %%
# load data from json
minion_data = load_minion_data('data/miniondata_1.json')
skill_data = load_data('data/skilldata_1.json')
    
# pick minions, unserialize dict to object
mnn1 = BattleMinion(minion_dict=minion_data, skill_dict=skill_data, mid=1)
mnn2 = BattleMinion(minion_dict=minion_data, skill_dict=skill_data, mid=2)
    
# assign minions to parties
party1 = Party([mnn1])
party2 = Party([mnn2])

wd1_params = {
    'minion_data':minion_data,
    'skill_data': skill_data,
    'party1': party1,
    'party2': party2,
    'battle_type': '1v1',
    'timelimit': 600,
    'tline': Timeline()
}

wd1 = World(**wd1_params)
    
_,_,_ = battle(wd1)
# Out:
# Party 1:  [1]
# Party 2:  [2]
# ------ Battle starts ------
# 0 mnn_fFree minion1 fast_move_1 is freed
# HP
#  {1: 1584.0, 2: 1605.0}
# MP
#  {1: 0, 2: 0}
# ---------------------------------
# 0 mnn_sFree minion1 super_move_1 is freed
# HP
#  {1: 1584.0, 2: 1605.0}
# MP
#  {1: 0, 2: 0}
# ---------------------------------
# 0 mnn_fFree minion2 fast_move_1 is freed
# HP
#  {1: 1584.0, 2: 1605.0}
# MP
#  {1: 0, 2: 0}
# ---------------------------------
# 0 mnn_sFree minion2 super_move_1 is freed
# HP
#  {1: 1584.0, 2: 1605.0}
# MP
#  {1: 0, 2: 0}
# ---------------------------------
# 0.1 mnnHurt minion1 attacks minion2 by fast_move_1, damage: 79
# HP
#  {1: 1584.0, 2: 1526.0}
# MP
#  {1: 16.0, 2: 24.0}
# ---------------------------------
# 0.1 mnnHurt minion2 attacks minion1 by fast_move_1, damage: 103
# HP
#  {1: 1481.0, 2: 1526.0}
# MP
#  {1: 47.0, 2: 45.0}
# ---------------------------------
# 0.5 mnn_fFree minion1 fast_move_1 is freed
# HP
#  {1: 1481.0, 2: 1526.0}
# MP
#  {1: 47.0, 2: 45.0}
# ---------------------------------
# 0.5 mnn_fFree minion2 fast_move_1 is freed
# HP
#  {1: 1481.0, 2: 1526.0}
# MP
#  {1: 47.0, 2: 45.0}
# ---------------------------------
# 0.6 mnnHurt minion1 attacks minion2 by fast_move_1, damage: 79
# HP
#  {1: 1481.0, 2: 1447.0}
# MP
#  {1: 63.0, 2: 69.0}
# ---------------------------------
# 0.6 mnnHurt minion2 attacks minion1 by fast_move_1, damage: 103
# HP
#  {1: 1378.0, 2: 1447.0}
# MP
#  {1: 94.0, 2: 90.0}
# ---------------------------------
# 1.0 mnn_fFree minion1 fast_move_1 is freed
# HP
#  {1: 1378.0, 2: 1447.0}
# MP
#  {1: 94.0, 2: 90.0}
# ---------------------------------
# 1.0 mnn_fFree minion2 fast_move_1 is freed
# HP
#  {1: 1378.0, 2: 1447.0}
# MP
#  {1: 94.0, 2: 90.0}
# ---------------------------------
# 1.1 mnnHurt minion2 attacks minion1 by super_move_1, damage: 4081
# HP
#  {1: 0, 2: 1447.0}
# MP
#  {1: 94.0, 2: 10.0}
# ---------------------------------
# Party 2 wins
