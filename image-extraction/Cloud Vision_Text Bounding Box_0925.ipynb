# %%
import io
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/Users/sibylhe/Documents/DR/image_extraction/Image Extraction-eecf9a57849d.json"
from google.cloud import vision
from google.cloud.vision import types

def detect_text(path):
    """Detects text in the file."""
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.types.Image(content=content)

    response = client.text_detection(image=image)
    texts = response.text_annotations
    print('Texts:')

    for text in texts:
        print('\n"{}"'.format(text.description))

        vertices = (['({},{})'.format(vertex.x, vertex.y)
                    for vertex in text.bounding_poly.vertices])

        print('bounds: {}'.format(','.join(vertices)))

# %%
import time

PATH_TO_TEST_IMAGES_DIR = '/Users/sibylhe/Documents/DR/image_extraction/image/smalltest/'
image_names = ['5adaae5dd1076.image.jpg', '138+E+14th+St,+New+York_5.jpg', 'walmart.jpeg', '161116143407-starbucks-store-780x439.jpg']
TEST_IMAGE_PATHS = [PATH_TO_TEST_IMAGES_DIR+image_name for image_name in image_names]

start = time.time()

for image_path in TEST_IMAGE_PATHS:
    detect_text(image_path)
    
end = time.time()
print('Elaspe: ',end-start,'s')
# 1 sec per image
# Out:
# Texts:
#
# "TARGET
# "
# bounds: (377,169),(541,169),(541,250),(377,250)
#
# "TARGET"
# bounds: (377,218),(530,169),(541,202),(387,250)
# Texts:
#
# "RADER OS
# "
# bounds: (403,264),(498,264),(498,278),(403,278)
#
# "RADER"
# bounds: (403,264),(456,264),(456,278),(403,278)
#
# "OS"
# bounds: (465,264),(498,264),(498,278),(465,278)
# Texts:
#
# "Walmarts
# Supercentre
# "
# bounds: (449,315),(845,315),(845,448),(449,448)
#
# "Walmarts"
# bounds: (452,315),(845,332),(841,409),(449,392)
#
# "Supercentre"
# bounds: (619,411),(806,415),(805,448),(618,444)
# Texts:
#
# "STARBUCKS COFFEE
# Your
# Perfected
# Latte
# STARBUCKS
# COFFEE
# "
# bounds: (87,17),(726,17),(726,409),(87,409)
#
# "STARBUCKS"
# bounds: (132,33),(452,24),(453,59),(133,69)
#
# "COFFEE"
# bounds: (473,23),(692,17),(693,54),(474,61)
#
# "Your"
# bounds: (473,246),(487,246),(487,251),(473,251)
#
# "Perfected"
# bounds: (480,255),(510,255),(510,261),(480,261)
#
# "Latte"
# bounds: (714,286),(726,286),(726,291),(714,291)
# ...
